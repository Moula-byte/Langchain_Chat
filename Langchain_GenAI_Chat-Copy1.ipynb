# %%
from google import genai

client = genai.Client(api_key="API_KEY")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="You are standup comedian, tell about python errors so that kids can also understand",
)

print(response.text)
# Out:
# (Lights dim, then bright spotlights hit you. You stride onto the stage, mic in hand, beaming. You're wearing something slightly quirky, maybe a t-shirt with a pixelated snake or a cartoon error message.)
#
# "What's up, future tech billionaires and coding wizards?! Are you ready to laugh, learn, and maybe accidentally debug your brains a little bit tonight?!"
#
# (Crowd cheers, hopefully some actual kids in the front row.)
#
# "Alright, alright! Settle down, you magnificent mini-programmers! My name is [Your Comedian Name], and I'm here tonight to talk about something near and dear to every coder's heart... and the cause of many a hair-pulling, desk-thumping, 'WHY WON'T YOU WORK?!' moment."
#
# (You lean in conspiratorially.)
#
# "We're talking about... **Python Errors!**"
#
# (You dramatically whisper "boo".)
#
# ...

# %%
# We ar accessing the gemini model using the API key using Langchain Package
from langchain_google_genai import ChatGoogleGenerativeAI

llm= ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key="AIzaSyAJT3AQzkM14eC3ORKM2ox5V7NUdxQWH68",
    temperature=0.3,# temperature is nothing but model thinking process
)
response=llm.invoke("Injection molding process")
print(response)
# Out:
# content="The injection molding process is a manufacturing process for producing parts by injecting molten material into a mold. It's a versatile and widely used technique for creating a vast array of plastic products, from simple toys to complex automotive components. Here's a breakdown of the process:\n\n**1. Design and Mold Creation:**\n\n*   **Part Design:** The process begins with a detailed design of the part to be manufactured. This design considers factors like functionality, aesthetics, material selection, and manufacturability. CAD (Computer-Aided Design) software is commonly used.\n*   **Mold Design:**  Based on the part design, a mold is designed and manufactured. The mold is a complex tool, typically made of hardened steel or aluminum. It consists of two main halves:\n    *   **Cavity Side (A-side):** Forms the external shape of the part.\n    *   **Core Side (B-side):** Forms the internal shape of the part.\n    *   **Runner System:** Channels that guide the molten plast
# ...
